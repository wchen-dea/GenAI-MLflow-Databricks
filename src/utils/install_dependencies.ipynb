# %% [markdown]
# # Install Dependencies
# Installs all Python packages required by the GenAI with MLflow demos.

# %%
# !pip install mlflow==3.14.0 mlflow-tracing==3.14.0 \
  openai>=1.0.0 anthropic>=0.49.0 \
  langchain>=1.2.7 langchain-openai databricks-langchain \
  langgraph>=0.3 \
  llama-index>=0.14.13 \
  litellm>=1.81.5 \
  ragas>=0.4.3 \
  gepa>=0.0.18 \
  openai-agents>=0.8.2 \
  deepagents>=0.1.0 \
  deepeval>=3.9.5 \
  crewai>=0.108.0 crewai-tools>=0.38.1 \
  python-dotenv>=1.0.0 \
  datasets>=4.5.0 \
  nest-asyncio>=1.6.0 \
  matplotlib>=3.7.0 numpy>=1.24.0 pandas>=2.0.0
